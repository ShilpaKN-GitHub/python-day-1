# %% [markdown]
# <a href="https://colab.research.google.com/github/ShilpaKN-GitHub/python-day-1/blob/master/Introduction_to_Python_%2C_Variables%2C_Data_Types_and_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **VARIABLES AND VALUES :**

# %%
3+4
#Addition of 2 number
# Out:
# 7

# %%
print(1+2+"hi")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-895a49f7c206> in <module>()
# ----> 1 print(1+2+"hi")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3*1**3

# %%
3*1**3
# Out:
# 3

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
1+2
# Out:
# 3

# %%
'''
            Variables and values :
----------------------------------------------------
Plate                   =         Pizza
container/variable      =         value/literal
  (left hand)                     (right hand)
 
x=15 , mia_age=15   //remember
#plate/container-variable
Variable name should always start with letter or underscore.
Variable name can't start with number.
Variable name can contain only alphabets , numbers and underscores.
#jan_days=march_days=may_days=31  When all the containers/variables have same value
#jan_days=31
#march_days=31
#may_days=31
ex:  mia=15    //correct !!------------>container/variable : mia      value:15
 
     _mia=15   //correct !!
 
     6mia=15    //wrong !!
 
     mia6=15    // correct !!
 
     mia@age=15 //wrong !!
     
#Assigning value to variable. mia=15   ,  _mia=15   , 6mia=15  , mia6=15    , mia@age=15 
 
'''

# %% [markdown]
# **DATA TYPES :**
#
# **1)intezer:**     Any number from -infinity to +infinity ex:3,-8,7776,2,-2
#
# **2)Float:**      Any decimal number ex:4.5,7,9998,1.0,-9.8,2.0,-2.0
#
# **3)String:**      " " or '' mean the same i.e., the thing that we have entered inside is called string .String can consist of any thing. ie., numbers , letters,symbols
#
# **4)Boolean:**     Binary numbers 0 and 1. 0-no, 1-yes     0/no-False     ,     1/yes-True

# %%
>>>var1 = 1 >>>var2 = 2 >>>var3 = "3" >>>print(var + var2 + var3)
# Out:
#   File "<ipython-input-1-721108839519>", line 1
#     >>>var1 = 1 >>>var2 = 2 >>>var3 = "3" >>>print(var + var2 + var3)
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![Capture;;.PNG](data:image/png;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %%
#integer 2,3-2
#float 2.0 , -2.0
#String "" or '' alphabets , numbers , special characters
#Boolean True / False

# %%
9/4
# Out:
# 2.25

# %%
9//4
# Out:
# 2

# %%
2.5//2
# Out:
# 1.0

# %%
# Examples of Arithmetic Operator 
a = 9
b = 4

# Addition of numbers 
add = a + b 

# Subtraction of numbers 
sub = a - b 

# Multiplication of number 
mul = a * b 

# Division(float) of number 
div1 = a / b 

# Division(floor) of number 
div2 = a // b 

# Modulo of both number 
mod = a % b #ex 50%7=1 even no --> num%2==0

# Power 
p = a ** b #2**3=8

# print results 
print(add) 
print(sub) 
print(mul) 
print(div1) 
print(div2) 
print(mod) 
print(p)
# Out:
# 13
# 5
# 36
# 2.25
# 2
# 1
# 6561

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %%
# Examples of Relational Operators 
a = 13
b = 33

# a > b is False 
print(a > b) 

# a < b is True 
print(a < b) 

# a == b is False 
print(a == b) 

# a != b is True 
print(a != b) 

# a >= b is False 
print(a >= b) 

# a <= b is True 
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ![4.jpg](data:image/jpeg;base64,...)
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
'''int a=5
a++
a=a+1
a+=1'''

# %% [markdown]
# ![5.jpg](data:image/jpeg;base64,...)

# %%
# Examples of Logical Operator 
a = True
b = False
  
# Print a and b is False 
print(a and b) 
  
# Print a or b is True 
print(a or b) 
  
# Print not a is False 
print(not a)
# Out:
# False
# True
# False

# %%
'''and 
TT --> True
TF --> False
FT --> False
FF --> False

or
TT --> True
TF --> True
FT --> True
FF --> False'''

# %% [markdown]
# ![6.jpg](data:image/jpeg;base64,...)

# %%
# Examples of Bitwise operators 
a = 10
b = 4
  
# Print bitwise AND operation   
print(a & b) 
  
# Print bitwise OR operation 
print(a | b) 
  
# Print bitwise NOT operation  
print(~a) 
  
# print bitwise XOR operation  
print(a ^ b) 
  
# print bitwise right shift operation  
print(a >> 2) 
  
# print bitwise left shift operation  
print(a << 2)
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %% [markdown]
# ## **Special operators:**
#
# is and is not are the identity operators both are used to check if two values are located on the same part of the memory. Two variables that are equal does not imply that they are identical.
#
# * is          True if the operands are identical
# * is not      True if the operands are not identical

# %%
# Examples of Identity operators 
a1 = 3
b1 = 3
a2 = 'whitehatjr'
b2 = 'whitehatjr'
a3 = [1,2,3] 
b3 = [1,2,3] 
  
  
print(a1 is not b1) 
  
  
print(a2 is b2) 
  
# Output is False, since lists are mutable. 
print(a3 is b3)
# Out:
# False
# True
# False
